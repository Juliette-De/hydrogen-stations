# %%
# import streamlit as st
import sys
import os
# from streamlit_folium import folium_static


sys.path.append("/Users/antoinerazeghi/Documents/Projects/AirLiquide/airliquide/")



import hub_clustering.streamlit_function as l
import plotly.graph_objects as go
import plotly.express as px

df = l.load_and_prepare()

df_bis = df.copy()
df_bis['Highway'] = df_bis.route.apply(lambda x:"Highway" if x[0]=='A' else "Other")

#select_options = st.multiselect(
#  'Select the roads you want to focus on',
#  ["All", "Highways", "Other"] + list(df_bis.route.unique()),
#   default='All')

select_options = 'All'

if 'All' in select_options:
  df_bis = df_bis
elif 'Highways' in select_options:
  df_bis = df_bis[df_bis.Highway == "Highway"]
elif 'Other' in select_options:
  df_bis = df_bis[df_bis.Highway != "Highway"]
else:
   df_bis = df_bis[df_bis.route.isin(select_options)]

default_frequency = 150
default_affluence = 0.25

options = ('Optimistic', 'Moderate', 'Conservative')
# selected_option = st.sidebar.radio('Select a traffic scenario', options)
selected_option = 'Optimistic'

# Set the default values for the sliders based on the selected option
if selected_option == 'Optimistic':
    default_frequency = 100
    default_affluence = 0.2
elif selected_option == 'Moderate':
    default_frequency = 150
    default_affluence = 0.25
else:
    default_frequency = 200
    default_affluence = 0.3

# Display the sliders for frequency and affluence
# frequency = st.sidebar.slider("Custom Frequency", 50, 300, default_frequency, step=25)
# affluence = st.sidebar.slider("Custom Affluence", float(0), float(1), default_affluence, step=0.05)

# st.title("Intermediate stations repartition : stations on roads & highways")

# try: 
#   m, df_info = l.intermediateStations(df_bis, frequency, affluence)
#  folium_static(m)
# except IndexError:
#     st.write('Please select atleast one road')
    
# st.write('Total number of stations : ', int(df_info.is_stationable.sum()))

# options_regions = st.multiselect("What scenario would you like to stimulate?", ('Optimistic', 'Moderate', 'Conservative'), ('Optimistic', 'Moderate', 'Conservative'))

l.intermediateStations_region(df)
# Out:
# ---------------------------------------------------------------------------
# CacheKeyNotFoundError                     Traceback (most recent call last)
# File ~/Documents/Projects/AirLiquide/env_al/lib/python3.9/site-packages/streamlit/runtime/caching/cache_utils.py:229, in CachedFunc._get_or_create_cached_value(self, func_args, func_kwargs)
#     228 try:
# --> 229     cached_result = cache.read_result(value_key)
#     230     return self._handle_cache_hit(cached_result)
#
# File ~/Documents/Projects/AirLiquide/env_al/lib/python3.9/site-packages/streamlit/runtime/caching/cache_data_api.py:515, in DataCache.read_result(self, key)
#     514     else:
# --> 515         raise e
#     517 try:
#
# File ~/Documents/Projects/AirLiquide/env_al/lib/python3.9/site-packages/streamlit/runtime/caching/cache_data_api.py:508, in DataCache.read_result(self, key)
#     507 try:
# --> 508     pickled_entry = self._read_from_mem_cache(key)
#     510 except CacheKeyNotFoundError as e:
#
# File ~/Documents/Projects/AirLiquide/env_al/lib/python3.9/site-packages/streamlit/runtime/caching/cache_data_api.py:606, in DataCache._read_from_mem_cache(self, key)
#     605 _LOGGER.debug("Memory cache MISS: %s", key)
# --> 606 raise CacheKeyNotFoundError("Key not found in mem cache")
#
# CacheKeyNotFoundError: Key not found in mem cache
#
# During handling of the above exception, another exception occurred:
#
# CacheKeyNotFoundError                     Traceback (most recent call last)
# File ~/Documents/Projects/AirLiquide/env_al/lib/python3.9/site-packages/streamlit/runtime/caching/cache_utils.py:277, in CachedFunc._handle_cache_miss(self, cache, value_key, func_args, func_kwargs)
#     276 try:
# --> 277     cached_result = cache.read_result(value_key)
#     278     # Another thread computed the value before us. Early exit!
#
# File ~/Documents/Projects/AirLiquide/env_al/lib/python3.9/site-packages/streamlit/runtime/caching/cache_data_api.py:515, in DataCache.read_result(self, key)
#     514     else:
# --> 515         raise e
#     517 try:
#
# File ~/Documents/Projects/AirLiquide/env_al/lib/python3.9/site-packages/streamlit/runtime/caching/cache_data_api.py:508, in DataCache.read_result(self, key)
#     507 try:
# --> 508     pickled_entry = self._read_from_mem_cache(key)
#     510 except CacheKeyNotFoundError as e:
#
# File ~/Documents/Projects/AirLiquide/env_al/lib/python3.9/site-packages/streamlit/runtime/caching/cache_data_api.py:606, in DataCache._read_from_mem_cache(self, key)
#     605 _LOGGER.debug("Memory cache MISS: %s", key)
# --> 606 raise CacheKeyNotFoundError("Key not found in mem cache")
#
# CacheKeyNotFoundError: Key not found in mem cache
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 15
#      12 import plotly.graph_objects as go
#      13 import plotly.express as px
# ---> 15 df = l.load_and_prepare()
#      17 df_bis = df.copy()
#      18 df_bis['Highway'] = df_bis.route.apply(lambda x:"Highway" if x[0]=='A' else "Other")
#
# File ~/Documents/Projects/AirLiquide/env_al/lib/python3.9/site-packages/streamlit/runtime/caching/cache_utils.py:178, in make_cached_func_wrapper.<locals>.wrapper(*args, **kwargs)
#     176 @functools.wraps(info.func)
#     177 def wrapper(*args, **kwargs):
# --> 178     return cached_func(*args, **kwargs)
#
# File ~/Documents/Projects/AirLiquide/env_al/lib/python3.9/site-packages/streamlit/runtime/caching/cache_utils.py:207, in CachedFunc.__call__(self, *args, **kwargs)
#     205 if self._info.show_spinner or isinstance(self._info.show_spinner, str):
#     206     with spinner(message):
# --> 207         return self._get_or_create_cached_value(args, kwargs)
#     208 else:
#     209     return self._get_or_create_cached_value(args, kwargs)
#
# File ~/Documents/Projects/AirLiquide/env_al/lib/python3.9/site-packages/streamlit/runtime/caching/cache_utils.py:232, in CachedFunc._get_or_create_cached_value(self, func_args, func_kwargs)
#     230     return self._handle_cache_hit(cached_result)
#     231 except CacheKeyNotFoundError:
# --> 232     return self._handle_cache_miss(cache, value_key, func_args, func_kwargs)
#
# File ~/Documents/Projects/AirLiquide/env_al/lib/python3.9/site-packages/streamlit/runtime/caching/cache_utils.py:286, in CachedFunc._handle_cache_miss(self, cache, value_key, func_args, func_kwargs)
#     281 except CacheKeyNotFoundError:
#     282     # We acquired the lock before any other thread. Compute the value!
#     283     with self._info.cached_message_replay_ctx.calling_cached_function(
#     284         self._info.func, self._info.allow_widgets
#     285     ):
# --> 286         computed_value = self._info.func(*func_args, **func_kwargs)
#     288     # We've computed our value, and now we need to write it back to the cache
#     289     # along with any "replay messages" that were generated during value computation.
#     290     messages = self._info.cached_message_replay_ctx._most_recent_messages
#
# File ~/Documents/Projects/AirLiquide/airliquide/hub_clustering/streamlit_function.py:11, in load_and_prepare()
#       9 @st.cache_data
#      10 def load_and_prepare():
# ---> 11     df = pd.read_csv("hub_clustering/df_clean.csv")
#      12     region_dep = pd.read_csv("hub_clustering/departements-region.csv", sep=";")
#      14     df["truck_traffic"] = df["TMJA"] * df["ratioPL"] / 100
#
# File ~/Documents/Projects/AirLiquide/env_al/lib/python3.9/site-packages/pandas/util/_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~/Documents/Projects/AirLiquide/env_al/lib/python3.9/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~/Documents/Projects/AirLiquide/env_al/lib/python3.9/site-packages/pandas/io/parsers/readers.py:950, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     935 kwds_defaults = _refine_defaults_read(
#     936     dialect,
#     937     delimiter,
#    (...)
#     946     defaults={"delimiter": ","},
#     947 )
#     948 kwds.update(kwds_defaults)
# --> 950 return _read(filepath_or_buffer, kwds)
#
# File ~/Documents/Projects/AirLiquide/env_al/lib/python3.9/site-packages/pandas/io/parsers/readers.py:605, in _read(filepath_or_buffer, kwds)
#     602 _validate_names(kwds.get("names", None))
#     604 # Create the parser.
# --> 605 parser = TextFileReader(filepath_or_buffer, **kwds)
#     607 if chunksize or iterator:
#     608     return parser
#
# File ~/Documents/Projects/AirLiquide/env_al/lib/python3.9/site-packages/pandas/io/parsers/readers.py:1442, in TextFileReader.__init__(self, f, engine, **kwds)
#    1439     self.options["has_index_names"] = kwds["has_index_names"]
#    1441 self.handles: IOHandles | None = None
# -> 1442 self._engine = self._make_engine(f, self.engine)
#
# File ~/Documents/Projects/AirLiquide/env_al/lib/python3.9/site-packages/pandas/io/parsers/readers.py:1735, in TextFileReader._make_engine(self, f, engine)
#    1733     if "b" not in mode:
#    1734         mode += "b"
# -> 1735 self.handles = get_handle(
#    1736     f,
#    1737     mode,
#    1738     encoding=self.options.get("encoding", None),
#    1739     compression=self.options.get("compression", None),
#    1740     memory_map=self.options.get("memory_map", False),
#    1741     is_text=is_text,
#    1742     errors=self.options.get("encoding_errors", "strict"),
#    1743     storage_options=self.options.get("storage_options", None),
#    1744 )
#    1745 assert self.handles is not None
#    1746 f = self.handles.handle
#
# File ~/Documents/Projects/AirLiquide/env_al/lib/python3.9/site-packages/pandas/io/common.py:856, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     851 elif isinstance(handle, str):
#     852     # Check whether the filename is to be opened in binary mode.
#     853     # Binary mode does not support 'encoding' and 'newline'.
#     854     if ioargs.encoding and "b" not in ioargs.mode:
#     855         # Encoding
# --> 856         handle = open(
#     857             handle,
#     858             ioargs.mode,
#     859             encoding=ioargs.encoding,
#     860             errors=errors,
#     861             newline="",
#     862         )
#     863     else:
#     864         # Binary mode
#     865         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'hub_clustering/df_clean.csv'
